# %% [markdown]
# <a href="https://colab.research.google.com/github/namozhdehi/KSR/blob/main/3_Baseline_Model_Ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import mean_squared_log_error as msle, mean_squared_error as mse, r2_score
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Reading the pre-processed dataset
df = pd.read_csv('Ecommerce_PreProcessing.csv')
df.head()
# Out:
#   InvoiceNo  StockCode  Description  Quantity InvoiceDate  UnitPrice  \
# 0    536365       3536         3919         6  2016-11-29       2.55
# 1    536365       2794         3927         6  2016-11-29       3.39
# 2    536365       3044          913         8  2016-11-29       2.75
# 3    536365       2985         1910         6  2016-11-29       3.39
# 4    536365       2984         2911         6  2016-11-29       3.39
#
#    CustomerID  Country  Invoice_year  Invoice_month  Invoice_DoM  Invoice_day  \
# 0        4047       36          2016             11           29            1
# 1        4047       36          2016             11           29            1
# 2        4047       36          2016             11           29            1
# 3        4047       36          2016             11           29            1
# 4        4047       36          2016             11           29            1
#
#    Invoice_DoW  Invoice_monthN
# 0            4               9
# 1            4               9
# 2            4               9
# 3            4               9
# 4            4               9

# %%
df = df[['StockCode',	'Quantity',	'Invoice_year', 'Invoice_month', 'Invoice_DoM',	'UnitPrice',	'CustomerID',	'Country']]

# %%
df.head()
# Out:
#    StockCode  Quantity  Invoice_year  Invoice_month  Invoice_DoM  UnitPrice  \
# 0       3536         6          2016             11           29       2.55
# 1       2794         6          2016             11           29       3.39
# 2       3044         8          2016             11           29       2.75
# 3       2985         6          2016             11           29       3.39
# 4       2984         6          2016             11           29       3.39
#
#    CustomerID  Country
# 0        4047       36
# 1        4047       36
# 2        4047       36
# 3        4047       36
# 4        4047       36

# %%
df.shape
# Out:
# (541895, 8)

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (541895, 8)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data_scaled = scaler.fit_transform(df)

# %% [markdown]
# K-Means Clustering

# %%
SSE_scaled = []

# %%
from sklearn.cluster import KMeans
for cluster in range(1,20):
    kmeans = KMeans( n_clusters = cluster)
    kmeans.fit(data_scaled)
    SSE_scaled.append(kmeans.inertia_)

# %%
plt.figure(figsize=(12,6))
frame_scaled = pd.DataFrame({'Cluster':range(1,20), 'SSE':SSE_scaled})
plt.plot(frame_scaled['Cluster'], frame_scaled['SSE'], marker='o')
plt.xlabel("Clusters")
plt.ylabel("SSE")
# Out:
# Text(0, 0.5, 'SSE')

# %%
kmeans = KMeans( n_clusters = 7)
kmeans.fit(data_scaled)
pred = kmeans.predict(data_scaled)

# %%
pred
# Out:
# array([5, 5, 5, ..., 1, 1, 1], dtype=int32)

# %%
frame = pd.DataFrame(data_scaled)

# %%
frame['cluster'] = pred

# %%
frame['cluster'].value_counts()
# Out:
# cluster
# 6    133935
# 2    129869
# 0    127658
# 3     73926
# 5     40832
# 1     35639
# 4        36
# Name: count, dtype: int64

# %%
frame.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.021276 -0.020466 -3.428903  1.003361  1.593456 -0.031357  0.916737
# 1  1.225784 -0.020466 -3.428903  1.003361  1.593456 -0.016333  0.916737
# 2  1.493807 -0.007804 -3.428903  1.003361  1.593456 -0.027780  0.916737
# 3  1.430553 -0.020466 -3.428903  1.003361  1.593456 -0.016333  0.916737
# 4  1.429481 -0.020466 -3.428903  1.003361  1.593456 -0.016333  0.916737
#
#           7  cluster
# 0  0.279655        5
# 1  0.279655        5
# 2  0.279655        5
# 3  0.279655        5
# 4  0.279655        5

# %% [markdown]
# Highly Valued Customers

# %%
# Identify the cluster with the least number of customers
cluster_counts = frame['cluster'].value_counts()

# Find the cluster(s) with the least number of members
least_members = cluster_counts.idxmin()
highly_valued_customers_count = cluster_counts[least_members]

print(f"The number of highly valued customers is: {highly_valued_customers_count}")
# Out:
# The number of highly valued customers is: 36
